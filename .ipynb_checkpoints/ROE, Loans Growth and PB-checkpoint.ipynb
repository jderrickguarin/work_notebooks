# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from statsmodels.tsa.stattools import adfuller, grangercausalitytests
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from itertools import combinations
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
data = os.path.join('datasets', 'roe_cof.csv')

df = pd.read_csv(data, parse_dates=[0], index_col=0, squeeze=True).dropna()


df.head(-1)
# Out:
#              ucb_roe  ucb_cof     fin_pe    fin_pb   loan_gth  asset_yld   rrr
# 2008-03-01  11.08000  3.12000  14.692117  1.784067   4.447821    7.37000  5.00
# 2008-06-01  10.59000  2.99000  12.801276  1.468649  16.208615    7.11000  5.25
# 2008-09-01   9.40000  3.03000  13.514477  1.603242  14.716742    7.27000  6.00
# 2008-12-01   7.17000  3.01000  15.569823  1.340741  12.149364    7.23000  5.50
# 2009-03-01   7.26000  3.03000  15.236230  1.236850  14.135784    7.56000  4.75
# 2009-06-01   8.65000  2.85000  19.284649  1.592710   6.770386    7.40000  4.25
# 2009-09-01   9.99000  2.72000  21.240830  1.882077   6.453792    7.24000  4.00
# 2009-12-01  11.38000  2.37000  20.324328  1.924171   8.652602    6.55000  4.00
# 2010-03-01  11.90000  2.25000  19.329883  1.911234   2.422627    6.55000  4.00
# 2010-06-01  11.77000  2.18000  19.397814  2.028665   6.179292    6.40000  4.00
# 2010-09-01  12.24000  2.10000  23.265870  2.458868   7.346533    6.29000  4.00
# 2010-12-01  12.72000  1.94000  22.066616  2.305063   3.820404    6.13000  4.00
# 2011-03-01  13.03000  1.92000  17.759799  2.001051   9.080291    5.60000  4.25
# 2011-06-01  13.30000  1.86000  18.339389  2.059238  12.817407    5.45000  4.50
# 2011-09-01  12.44000  1.91000  15.798511  2.011608  12.240323    5.52000  4.50
# 2011-12-01  12.58000  1.82000  16.958199  2.110544  13.738251    5.13000  4.50
# 2012-03-01  13.09000  1.88000  21.017099  2.474907  15.081493    5.24000  4.00
# 2012-06-01  12.78000  1.78000  19.948676  2.457635  12.168930    5.03000  4.00
# 2012-09-01  12.33000  1.74000  21.052621  2.574955  13.590634    4.93000  3.75
# 2012-12-01  12.67000  1.61000  23.513474  2.949215  13.474709    4.72000  3.50
# 2013-03-01  14.67000  1.62000  24.881810  3.249360  12.772661    4.74000  3.50
# 2013-06-01  15.79000  1.44000  20.686801  2.679222  10.453893    4.48000  3.50
# 2013-09-01  15.15000  1.28000  18.807525  2.426054  13.960756    4.28000  3.50
# 2013-12-01  13.65000  1.09000  16.643590  2.191202  15.805440    4.01000  3.50
# 2014-03-01  10.06000  1.03000  18.212056  2.255542  19.592385    4.09000  3.50
# 2014-06-01   9.83000  0.96000  18.780904  2.282194  19.515210    4.06000  3.50
# 2014-09-01   9.89000  0.95000  21.141755  2.521755  19.285364    4.01000  4.00
# 2014-12-01  10.96000  0.90000  20.483566  2.472684  19.102237    3.80000  4.00
# 2015-03-01  11.07000  0.93000  21.098118  2.494302  14.288471    3.87000  4.00
# 2015-06-01  10.70000  0.97000  19.990732  2.350402  12.658761    3.88000  4.00
# 2015-09-01  10.09000  0.98000  18.479546  2.232508  11.438815    3.90000  4.00
# 2015-12-01   9.40000  0.95000  18.344542  2.258926  11.914353    3.81000  4.00
# 2016-03-01   9.80183  0.98730  18.969589  2.084147  13.584904    3.91170  4.00
# 2016-06-01   9.81691  0.98974  20.201351  2.251893  15.844298    3.92230  3.00
# 2016-09-01   9.96523  0.97946  16.849956  1.986458  16.301993    3.89526  3.00
# 2016-12-01  10.49208  0.93487  15.540247  1.766915  16.620311    3.77104  3.00
# 2017-03-01   9.88228  0.94717  16.119405  1.697431  17.830078    3.82603  3.00
# 2017-06-01   9.64741  0.94547  16.807109  1.749295  17.998388    3.84840  3.00
# 2017-09-01   9.66078  0.96530  16.928236  1.832665  19.632003    3.92043  3.00
# 2017-12-01   9.96241  0.95653  17.997547  2.052229  16.466921    3.90389  3.00
# 2018-03-01   9.95263  1.02352  15.781228  1.672922  17.278040    4.01439  3.00
# 2018-06-01   9.34816  1.09323  14.004171  1.472934  16.590819    4.09876  3.50
# 2018-09-01   9.30379  1.18844  13.101102  1.412275  15.612259    4.22007  4.50
# 2018-12-01   9.34742  1.33279  13.707117  1.469048  13.674522    4.37440  4.75
# 2019-03-01   9.64210  1.57038  13.713269  1.357537  11.026439    4.70783  4.75
# 2019-06-01   9.87013  1.78592  13.409482  1.338190  10.006393    4.97165  4.50
# 2019-09-01  10.37737  1.90492  13.438428  1.296462   8.833090    5.12113  4.00
# 2019-12-01  10.69866  1.83289  13.089926  1.309916   8.813143    5.07614  4.00
# 2020-03-01  10.59261  1.71990   9.753470  0.782770  11.046929    5.11104  3.25
# 2020-06-01   9.17967  1.52807  10.365674  0.832332   5.154059    5.04642  2.25

# %%
sns.set(style="darkgrid")

fig = plt.figure(figsize=(16,6))

plt.plot(df.asset_yld, color='darkred', label='Asset Yields')
plt.plot(df.ucb_cof, color='tab:blue', label='Cost of Funds')
plt.plot(df.rrr, color='gray', label='Policy Rates')
plt.title('Policy Effects to Asset Yields & Cost of Funds')
plt.legend()
plt.xlabel('Years')

plt.xticks(rotation=90)

plt.show()
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
def all_dist():
    fig = plt.figure(figsize=(8,12))

    plt.subplot(3,1,1)
    plt.hist(df.asset_yld)
    plt.title('Asset Yields')
    plt.ylabel('Count')

    plt.subplot(3,1,2)
    plt.hist(df.ucb_cof)
    plt.title('Cost of Funds')
    plt.ylabel('Count')

    plt.subplot(3, 1, 3)
    plt.hist(df.rrr)
    plt.title('RRR')
    plt.ylabel('Count')

    
all_dist()

# %%
#testing for stationarity
def adf_test(series, name=None, num=None):
    result = adfuller(series)
    if name == None:
        name = str(series.name)
    if num != None:
        name = 'Series %s' % str(num)
    print('\n%s:' %name)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])

policy = df.rrr
cof = df.ucb_cof
lo

adf_test(roe)
print('Sample size: %s' %len(roe))
adf_test(loans)
print('Sample size: %s' %len(loans))
adf_test(pb)
print('Sample size: %s' %len(pb))
adf_test(pe)
print('Sample size: %s' %len(pe))
# Out:
# ucb_cof:
# ADF Statistic: -2.345688
# p-value: 0.157656
# Sample size: 51
#
# asset_yld:
# ADF Statistic: -2.159321
# p-value: 0.221339
# Sample size: 51
#
# rrr:
# ADF Statistic: -2.515455
# p-value: 0.111759
# Sample size: 51

# %% [markdown]
# ### Stationarize

# %%
# The following code consolidates transofrmation steps into one
def normalize(series):
    ave, stdev = series.mean(), series.std()
    series = (series-ave)/stdev
    return series

def annual_vol(series):
    stdevs = series.groupby(series.index.year).std()
    return series.index.map(lambda d: stdevs.loc[d.year])

def variance_correct(series):
    return series/annual_vol(series)

def qtr_mean(series):
    means = series.groupby(series.index.month).mean()
    return series.index.map(lambda d: means.loc[d.month])

def seasonality_correct(series):
    return series - qtr_mean(series)

def make_stationary(*data, plot=False, headers=True):
    stdata = []
    for d in data:
        if headers == True:
            header = d.name
        d = normalize(d)
        d = d.diff().fillna(method="bfill")
        d = variance_correct(d)
        #d = seasonality_correct(d).fillna(method="bfill")
        d.name = header
        stdata.append(d)
        
    if len(stdata) == 1:
        return stdata[0]
    else:
        return stdata

# %%
series = [roe, loans, pb, pe]
nseries = []

for s in series:
    header = s.name
    s = normalize(s)
    s = s.diff().fillna(method="bfill")
    s = variance_correct(s).fillna(method="bfill")
    s = s.replace([np.inf, -np.inf], np.nan).dropna()
    s.name = header
    nseries.append(s)
    adf_test(s)
    print('Sample size: %s' %len(s))

fig = plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
plt.hist(nseries[0])
plt.title('MSCI Financials F12 EPS')
plt.ylabel('Count')

plt.subplot(2,2,2)
plt.hist(nseries[1])
plt.title('MSCI Financials F12 P/B')
plt.ylabel('Count')

plt.subplot(2,2,3)
plt.hist(nseries[2])
plt.title('Reverse Repurchase Rate')
plt.ylabel('Count')

plt.subplot(2,2,4)
plt.hist(nseries[3])
plt.title('Reverse Repurchase Rate')
plt.ylabel('Count')

plt.show()

sdf = pd.concat(nseries, axis=1).fillna(method="ffill")
# Out:
# ucb_cof:
# ADF Statistic: -9.254493
# p-value: 0.000000
# Sample size: 50
#
# asset_yld:
# ADF Statistic: -9.182520
# p-value: 0.000000
# Sample size: 50
#
# rrr:
# ADF Statistic: -9.134833
# p-value: 0.000000
# Sample size: 50

# %%
adf_test(st_bonds)
print('Sample size: %s' %len(st_bonds))
adf_test(st_policy)
print('Sample size: %s' %len(st_policy))
# Out:
# lt_bond:
# ADF Statistic: -13.541642
# p-value: 0.000000
# Sample size: 420
#
# rrr:
# ADF Statistic: -6.940135
# p-value: 0.000000
# Sample size: 420

# %%
sns.set(style="darkgrid")

fig = plt.figure(figsize=(20,18))

plt.subplot(2, 1, 1)
plt.plot(sdf.ucb_roe, color='darkred', label='Return to Equity')
plt.plot(sdf.loan_gth, color='tab:blue', label='Loans Growth')
plt.plot(sdf.fin_pb, color='gray', label='MSCI Financials PB')
plt.title('ROE and Loans vs PB')
plt.legend()
plt.xlabel('Years')
plt.axhline(linewidth=1, linestyle='dashed', color='k')

plt.subplot(2, 1, 2)
plt.plot(sdf.ucb_roe, color='darkred', label='Return to Equity')
plt.plot(sdf.loan_gth, color='tab:blue', label='Loans Growth')
plt.plot(sdf.fin_pe, color='gray', label='MSCI Financials PE')
plt.title('ROE and Loans vs PE')
plt.legend()
plt.xlabel('Years')
plt.axhline(linewidth=1, linestyle='dashed', color='k')

plt.show()

# %% [markdown]
# ### Testing Causality

# %%
def granger(s1, s2, lag=12):
    granger_df = pd.concat([s1, s2], axis=1).dropna()
    grangercausalitytests(granger_df, lag)

print('Testing causality\n')
print('ROE -> PB')
granger(sdf.ucb_roe,sdf.fin_pb)
print('----------------------------\n')
print('ROE -> PE')
granger(sdf.ucb_roe,sdf.fin_pe)
print('----------------------------\n')
print('Loans Growth -> PB')
granger(sdf.loan_gth,sdf.fin_pb)
print('----------------------------\n')
print('Loans Growth -> PE')
granger(sdf.loan_gth,sdf.fin_pe)
# Out:
# Testing causality
#
# ROE -> PB
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.8464  , p=0.0982  , df_denom=47, df_num=1
# ssr based chi2 test:   chi2=3.0281  , p=0.0818  , df=1
# likelihood ratio test: chi2=2.9400  , p=0.0864  , df=1
# parameter F test:         F=2.8464  , p=0.0982  , df_denom=47, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9997  , p=0.3762  , df_denom=44, df_num=2
# ssr based chi2 test:   chi2=2.2265  , p=0.3285  , df=2
# likelihood ratio test: chi2=2.1774  , p=0.3367  , df=2
# parameter F test:         F=0.9997  , p=0.3762  , df_denom=44, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4110  , p=0.7459  , df_denom=41, df_num=3
# ssr based chi2 test:   chi2=1.4436  , p=0.6953  , df=3
# likelihood ratio test: chi2=1.4223  , p=0.7003  , df=3
# parameter F test:         F=0.4110  , p=0.7459  , df_denom=41, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6278  , p=0.1872  , df_denom=38, df_num=4
# ssr based chi2 test:   chi2=8.0534  , p=0.0896  , df=4
# likelihood ratio test: chi2=7.4333  , p=0.1147  , df=4
# parameter F test:         F=1.6278  , p=0.1872  , df_denom=38, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2255  , p=0.3179  , df_denom=35, df_num=5
# ssr based chi2 test:   chi2=8.0531  , p=0.1533  , df=5
# likelihood ratio test: chi2=7.4210  , p=0.1912  , df=5
# parameter F test:         F=1.2255  , p=0.3179  , df_denom=35, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3623  , p=0.2596  , df_denom=32, df_num=6
# ssr based chi2 test:   chi2=11.4940 , p=0.0743  , df=6
# likelihood ratio test: chi2=10.2363 , p=0.1150  , df=6
# parameter F test:         F=1.3623  , p=0.2596  , df_denom=32, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2109  , p=0.3284  , df_denom=29, df_num=7
# ssr based chi2 test:   chi2=12.8602 , p=0.0756  , df=7
# likelihood ratio test: chi2=11.2819 , p=0.1268  , df=7
# parameter F test:         F=1.2109  , p=0.3284  , df_denom=29, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9412  , p=0.5007  , df_denom=26, df_num=8
# ssr based chi2 test:   chi2=12.4526 , p=0.1321  , df=8
# likelihood ratio test: chi2=10.9361 , p=0.2053  , df=8
# parameter F test:         F=0.9412  , p=0.5007  , df_denom=26, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7678  , p=0.6466  , df_denom=23, df_num=9
# ssr based chi2 test:   chi2=12.6180 , p=0.1807  , df=9
# likelihood ratio test: chi2=11.0331 , p=0.2734  , df=9
# parameter F test:         F=0.7678  , p=0.6466  , df_denom=23, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9003  , p=0.5501  , df_denom=20, df_num=10
# ssr based chi2 test:   chi2=18.4564 , p=0.0477  , df=10
# likelihood ratio test: chi2=15.2385 , p=0.1236  , df=10
# parameter F test:         F=0.9003  , p=0.5501  , df_denom=20, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=1.7545  , p=0.1441  , df_denom=17, df_num=11
# ssr based chi2 test:   chi2=45.4115 , p=0.0000  , df=11
# likelihood ratio test: chi2=30.3440 , p=0.0014  , df=11
# parameter F test:         F=1.7545  , p=0.1441  , df_denom=17, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=1.5769  , p=0.2065  , df_denom=14, df_num=12
# ssr based chi2 test:   chi2=52.7151 , p=0.0000  , df=12
# likelihood ratio test: chi2=33.3499 , p=0.0009  , df=12
# parameter F test:         F=1.5769  , p=0.2065  , df_denom=14, df_num=12
# ----------------------------
#
# ROE -> PE
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9602  , p=0.1681  , df_denom=47, df_num=1
# ssr based chi2 test:   chi2=2.0853  , p=0.1487  , df=1
# likelihood ratio test: chi2=2.0430  , p=0.1529  , df=1
# parameter F test:         F=1.9602  , p=0.1681  , df_denom=47, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7189  , p=0.4929  , df_denom=44, df_num=2
# ssr based chi2 test:   chi2=1.6011  , p=0.4491  , df=2
# likelihood ratio test: chi2=1.5755  , p=0.4549  , df=2
# parameter F test:         F=0.7189  , p=0.4929  , df_denom=44, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1783  , p=0.9105  , df_denom=41, df_num=3
# ssr based chi2 test:   chi2=0.6262  , p=0.8904  , df=3
# likelihood ratio test: chi2=0.6221  , p=0.8913  , df=3
# parameter F test:         F=0.1783  , p=0.9105  , df_denom=41, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7329  , p=0.5752  , df_denom=38, df_num=4
# ssr based chi2 test:   chi2=3.6261  , p=0.4590  , df=4
# likelihood ratio test: chi2=3.4930  , p=0.4789  , df=4
# parameter F test:         F=0.7329  , p=0.5752  , df_denom=38, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5256  , p=0.7552  , df_denom=35, df_num=5
# ssr based chi2 test:   chi2=3.4540  , p=0.6304  , df=5
# likelihood ratio test: chi2=3.3305  , p=0.6492  , df=5
# parameter F test:         F=0.5256  , p=0.7552  , df_denom=35, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5806  , p=0.7430  , df_denom=32, df_num=6
# ssr based chi2 test:   chi2=4.8987  , p=0.5569  , df=6
# likelihood ratio test: chi2=4.6499  , p=0.5894  , df=6
# parameter F test:         F=0.5806  , p=0.7430  , df_denom=32, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1669  , p=0.3515  , df_denom=29, df_num=7
# ssr based chi2 test:   chi2=12.3933 , p=0.0883  , df=7
# likelihood ratio test: chi2=10.9191 , p=0.1422  , df=7
# parameter F test:         F=1.1669  , p=0.3515  , df_denom=29, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9790  , p=0.4739  , df_denom=26, df_num=8
# ssr based chi2 test:   chi2=12.9529 , p=0.1135  , df=8
# likelihood ratio test: chi2=11.3224 , p=0.1841  , df=8
# parameter F test:         F=0.9790  , p=0.4739  , df_denom=26, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2802  , p=0.2994  , df_denom=23, df_num=9
# ssr based chi2 test:   chi2=21.0405 , p=0.0125  , df=9
# likelihood ratio test: chi2=17.0565 , p=0.0478  , df=9
# parameter F test:         F=1.2802  , p=0.2994  , df_denom=23, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5092  , p=0.2077  , df_denom=20, df_num=10
# ssr based chi2 test:   chi2=30.9381 , p=0.0006  , df=10
# likelihood ratio test: chi2=23.0516 , p=0.0106  , df=10
# parameter F test:         F=1.5092  , p=0.2077  , df_denom=20, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.9766  , p=0.5012  , df_denom=17, df_num=11
# ssr based chi2 test:   chi2=25.2768 , p=0.0083  , df=11
# likelihood ratio test: chi2=19.5903 , p=0.0513  , df=11
# parameter F test:         F=0.9766  , p=0.5012  , df_denom=17, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.7509  , p=0.6872  , df_denom=14, df_num=12
# ssr based chi2 test:   chi2=25.1032 , p=0.0143  , df=12
# likelihood ratio test: chi2=19.3803 , p=0.0798  , df=12
# parameter F test:         F=0.7509  , p=0.6872  , df_denom=14, df_num=12
# ----------------------------
#
# Loans Growth -> PB
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8491  , p=0.3615  , df_denom=47, df_num=1
# ssr based chi2 test:   chi2=0.9032  , p=0.3419  , df=1
# likelihood ratio test: chi2=0.8952  , p=0.3441  , df=1
# parameter F test:         F=0.8491  , p=0.3615  , df_denom=47, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5098  , p=0.6041  , df_denom=44, df_num=2
# ssr based chi2 test:   chi2=1.1355  , p=0.5668  , df=2
# likelihood ratio test: chi2=1.1225  , p=0.5705  , df=2
# parameter F test:         F=0.5098  , p=0.6041  , df_denom=44, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3828  , p=0.7659  , df_denom=41, df_num=3
# ssr based chi2 test:   chi2=1.3445  , p=0.7186  , df=3
# likelihood ratio test: chi2=1.3260  , p=0.7230  , df=3
# parameter F test:         F=0.3828  , p=0.7659  , df_denom=41, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3313  , p=0.8552  , df_denom=38, df_num=4
# ssr based chi2 test:   chi2=1.6393  , p=0.8017  , df=4
# likelihood ratio test: chi2=1.6113  , p=0.8068  , df=4
# parameter F test:         F=0.3313  , p=0.8552  , df_denom=38, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4624  , p=0.8014  , df_denom=35, df_num=5
# ssr based chi2 test:   chi2=3.0388  , p=0.6940  , df=5
# likelihood ratio test: chi2=2.9426  , p=0.7088  , df=5
# parameter F test:         F=0.4624  , p=0.8014  , df_denom=35, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3497  , p=0.9048  , df_denom=32, df_num=6
# ssr based chi2 test:   chi2=2.9508  , p=0.8150  , df=6
# likelihood ratio test: chi2=2.8581  , p=0.8264  , df=6
# parameter F test:         F=0.3497  , p=0.9048  , df_denom=32, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9082  , p=0.5139  , df_denom=29, df_num=7
# ssr based chi2 test:   chi2=9.6461  , p=0.2095  , df=7
# likelihood ratio test: chi2=8.7216  , p=0.2733  , df=7
# parameter F test:         F=0.9082  , p=0.5139  , df_denom=29, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9281  , p=0.5102  , df_denom=26, df_num=8
# ssr based chi2 test:   chi2=12.2789 , p=0.1392  , df=8
# likelihood ratio test: chi2=10.8012 , p=0.2132  , df=8
# parameter F test:         F=0.9281  , p=0.5102  , df_denom=26, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6457  , p=0.7471  , df_denom=23, df_num=9
# ssr based chi2 test:   chi2=10.6125 , p=0.3032  , df=9
# likelihood ratio test: chi2=9.4620  , p=0.3958  , df=9
# parameter F test:         F=0.6457  , p=0.7471  , df_denom=23, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5365  , p=0.8442  , df_denom=20, df_num=10
# ssr based chi2 test:   chi2=10.9982 , p=0.3577  , df=10
# likelihood ratio test: chi2=9.7431  , p=0.4633  , df=10
# parameter F test:         F=0.5365  , p=0.8442  , df_denom=20, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.5585  , p=0.8361  , df_denom=17, df_num=11
# ssr based chi2 test:   chi2=14.4548 , p=0.2088  , df=11
# likelihood ratio test: chi2=12.3397 , p=0.3387  , df=11
# parameter F test:         F=0.5585  , p=0.8361  , df_denom=17, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.4575  , p=0.9091  , df_denom=14, df_num=12
# ssr based chi2 test:   chi2=15.2920 , p=0.2259  , df=12
# likelihood ratio test: chi2=12.9018 , p=0.3762  , df=12
# parameter F test:         F=0.4575  , p=0.9091  , df_denom=14, df_num=12
# ----------------------------
#
# Loans Growth -> PE
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2109  , p=0.6481  , df_denom=47, df_num=1
# ssr based chi2 test:   chi2=0.2244  , p=0.6357  , df=1
# likelihood ratio test: chi2=0.2239  , p=0.6361  , df=1
# parameter F test:         F=0.2109  , p=0.6481  , df_denom=47, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1623  , p=0.8507  , df_denom=44, df_num=2
# ssr based chi2 test:   chi2=0.3614  , p=0.8347  , df=2
# likelihood ratio test: chi2=0.3601  , p=0.8352  , df=2
# parameter F test:         F=0.1623  , p=0.8507  , df_denom=44, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2620  , p=0.8523  , df_denom=41, df_num=3
# ssr based chi2 test:   chi2=0.9203  , p=0.8205  , df=3
# likelihood ratio test: chi2=0.9115  , p=0.8226  , df=3
# parameter F test:         F=0.2620  , p=0.8523  , df_denom=41, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0640  , p=0.9922  , df_denom=38, df_num=4
# ssr based chi2 test:   chi2=0.3166  , p=0.9887  , df=4
# likelihood ratio test: chi2=0.3155  , p=0.9888  , df=4
# parameter F test:         F=0.0640  , p=0.9922  , df_denom=38, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.0909  , p=0.9932  , df_denom=35, df_num=5
# ssr based chi2 test:   chi2=0.5970  , p=0.9881  , df=5
# likelihood ratio test: chi2=0.5932  , p=0.9883  , df=5
# parameter F test:         F=0.0909  , p=0.9932  , df_denom=35, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.0928  , p=0.9966  , df_denom=32, df_num=6
# ssr based chi2 test:   chi2=0.7832  , p=0.9925  , df=6
# likelihood ratio test: chi2=0.7765  , p=0.9927  , df=6
# parameter F test:         F=0.0928  , p=0.9966  , df_denom=32, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.1386  , p=0.9943  , df_denom=29, df_num=7
# ssr based chi2 test:   chi2=1.4721  , p=0.9833  , df=7
# likelihood ratio test: chi2=1.4480  , p=0.9841  , df=7
# parameter F test:         F=0.1386  , p=0.9943  , df_denom=29, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.1880  , p=0.9904  , df_denom=26, df_num=8
# ssr based chi2 test:   chi2=2.4880  , p=0.9623  , df=8
# likelihood ratio test: chi2=2.4186  , p=0.9654  , df=8
# parameter F test:         F=0.1880  , p=0.9904  , df_denom=26, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.1928  , p=0.9927  , df_denom=23, df_num=9
# ssr based chi2 test:   chi2=3.1685  , p=0.9572  , df=9
# likelihood ratio test: chi2=3.0546  , p=0.9621  , df=9
# parameter F test:         F=0.1928  , p=0.9927  , df_denom=23, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3683  , p=0.9465  , df_denom=20, df_num=10
# ssr based chi2 test:   chi2=7.5502  , p=0.6727  , df=10
# likelihood ratio test: chi2=6.9300  , p=0.7320  , df=10
# parameter F test:         F=0.3683  , p=0.9465  , df_denom=20, df_num=10
#
# Granger Causality
# number of lags (no zero) 11
# ssr based F test:         F=0.4591  , p=0.9042  , df_denom=17, df_num=11
# ssr based chi2 test:   chi2=11.8820 , p=0.3726  , df=11
# likelihood ratio test: chi2=10.4037 , p=0.4945  , df=11
# parameter F test:         F=0.4591  , p=0.9042  , df_denom=17, df_num=11
#
# Granger Causality
# number of lags (no zero) 12
# ssr based F test:         F=0.4650  , p=0.9045  , df_denom=14, df_num=12
# ssr based chi2 test:   chi2=15.5450 , p=0.2130  , df=12
# likelihood ratio test: chi2=13.0831 , p=0.3630  , df=12
# parameter F test:         F=0.4650  , p=0.9045  , df_denom=14, df_num=12

# %% [markdown]
# ### Fitting VAR Model

# %%
### AUTOMATE MODEL SELECTION
def fit_tsmodel(data, model='VAR', lags=4):
    models = ['VAR','SARIMAX']

    if model in models:
        if model == models[0]:
            model = VAR
        elif model == models[1]:
            model == SARIMAX
    else:
        print('Model not supported')
        return None
    
    fmodel = model(data)          
    res = fmodel.fit(maxlags=lags)
    return res

# %%
def create_df(*series):
    df = pd.concat(series, axis=1).dropna()
    n = []
    for i in series:
        n.append(i.name)
    df.columns = n
    return df

res = fit_tsmodel(sdf,lags=4)
res.summary()
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency QS-DEC will be used.
#   % freq, ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 08, Jan, 2021
# Time:                     14:06:53
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    3.37442
# Nobs:                     47.0000    HQIC:                   1.70491
# Log likelihood:          -215.154    FPE:                    2.30421
# AIC:                     0.697614    Det(Omega_mle):        0.670184
# --------------------------------------------------------------------
# Results for equation ucb_roe
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const               0.322694         0.189681            1.701           0.089
# L1.ucb_roe          0.415854         0.149588            2.780           0.005
# L1.loan_gth        -0.120505         0.173382           -0.695           0.487
# L1.fin_pb           0.850449         0.301437            2.821           0.005
# L1.fin_pe          -0.442768         0.290832           -1.522           0.128
# L2.ucb_roe         -0.188524         0.161267           -1.169           0.242
# L2.loan_gth        -0.438287         0.185269           -2.366           0.018
# L2.fin_pb          -0.343235         0.270096           -1.271           0.204
# L2.fin_pe           0.194217         0.259418            0.749           0.454
# L3.ucb_roe          0.152677         0.175930            0.868           0.385
# L3.loan_gth         0.097205         0.192512            0.505           0.614
# L3.fin_pb          -0.455600         0.266649           -1.709           0.088
# L3.fin_pe           0.160706         0.254391            0.632           0.528
# L4.ucb_roe         -0.340250         0.173910           -1.956           0.050
# L4.loan_gth         0.047908         0.198866            0.241           0.810
# L4.fin_pb           0.347593         0.283772            1.225           0.221
# L4.fin_pe          -0.638108         0.270713           -2.357           0.018
# ==============================================================================
#
# Results for equation loan_gth
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.031604         0.190013           -0.166           0.868
# L1.ucb_roe          0.030709         0.149850            0.205           0.838
# L1.loan_gth         0.281407         0.173686            1.620           0.105
# L1.fin_pb          -0.357312         0.301964           -1.183           0.237
# L1.fin_pe           0.281312         0.291340            0.966           0.334
# L2.ucb_roe          0.009398         0.161548            0.058           0.954
# L2.loan_gth         0.226973         0.185593            1.223           0.221
# L2.fin_pb          -0.041118         0.270568           -0.152           0.879
# L2.fin_pe          -0.057798         0.259872           -0.222           0.824
# L3.ucb_roe          0.021164         0.176238            0.120           0.904
# L3.loan_gth         0.210510         0.192848            1.092           0.275
# L3.fin_pb           0.221214         0.267115            0.828           0.408
# L3.fin_pe          -0.108098         0.254836           -0.424           0.671
# L4.ucb_roe         -0.140263         0.174214           -0.805           0.421
# L4.loan_gth        -0.440573         0.199214           -2.212           0.027
# L4.fin_pb          -0.024507         0.284268           -0.086           0.931
# L4.fin_pe           0.105344         0.271186            0.388           0.698
# ==============================================================================
#
# Results for equation fin_pb
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.051859         0.170435           -0.304           0.761
# L1.ucb_roe          0.112745         0.134410            0.839           0.402
# L1.loan_gth         0.166731         0.155790            1.070           0.285
# L1.fin_pb           0.328112         0.270851            1.211           0.226
# L1.fin_pe          -0.202946         0.261322           -0.777           0.437
# L2.ucb_roe         -0.348206         0.144903           -2.403           0.016
# L2.loan_gth        -0.196218         0.166470           -1.179           0.239
# L2.fin_pb          -0.112396         0.242690           -0.463           0.643
# L2.fin_pe           0.200069         0.233096            0.858           0.391
# L3.ucb_roe          0.232564         0.158079            1.471           0.141
# L3.loan_gth         0.089293         0.172978            0.516           0.606
# L3.fin_pb          -0.380020         0.239593           -1.586           0.113
# L3.fin_pe           0.236157         0.228578            1.033           0.302
# L4.ucb_roe          0.122237         0.156264            0.782           0.434
# L4.loan_gth         0.283119         0.178688            1.584           0.113
# L4.fin_pb           0.327794         0.254978            1.286           0.199
# L4.fin_pe          -0.321150         0.243244           -1.320           0.187
# ==============================================================================
#
# Results for equation fin_pe
# ==============================================================================
#                  coefficient       std. error           t-stat            prob
# ------------------------------------------------------------------------------
# const              -0.055579         0.158251           -0.351           0.725
# L1.ucb_roe          0.029953         0.124802            0.240           0.810
# L1.loan_gth         0.078908         0.144653            0.545           0.585
# L1.fin_pb           0.430577         0.251490            1.712           0.087
# L1.fin_pe          -0.479686         0.242641           -1.977           0.048
# L2.ucb_roe         -0.197083         0.134545           -1.465           0.143
# L2.loan_gth        -0.199962         0.154570           -1.294           0.196
# L2.fin_pb          -0.096231         0.225342           -0.427           0.669
# L2.fin_pe           0.049464         0.216433            0.229           0.819
# L3.ucb_roe         -0.021447         0.146779           -0.146           0.884
# L3.loan_gth         0.208265         0.160613            1.297           0.195
# L3.fin_pb          -0.524622         0.222466           -2.358           0.018
# L3.fin_pe           0.228944         0.212239            1.079           0.281
# L4.ucb_roe          0.270665         0.145094            1.865           0.062
# L4.loan_gth         0.587397         0.165914            3.540           0.000
# L4.fin_pb           0.160187         0.236751            0.677           0.499
# L4.fin_pe          -0.267616         0.225856           -1.185           0.236
# ==============================================================================
#
# Correlation matrix of residuals
#              ucb_roe  loan_gth    fin_pb    fin_pe
# ucb_roe     1.000000 -0.049430 -0.003965  0.145094
# loan_gth   -0.049430  1.000000  0.159500  0.170924
# fin_pb     -0.003965  0.159500  1.000000  0.789109
# fin_pe      0.145094  0.170924  0.789109  1.000000

# %%
print(r2_score(res.fittedvalues['fin_pe']+res.resid['fin_pe'],
  res.fittedvalues['fin_pe']))

print(r2_score(res.fittedvalues['fin_pb']+res.resid['fin_pb'],
  res.fittedvalues['fin_pb']))
# Out:
# 0.5415740177827701
# 0.39762940908053257

# %%
irf = res.irf(10)
irf.plot(orth=False)

# %% [markdown]
# ***The y-axis is given in standard deviations and x-axis in lag-periods.***
