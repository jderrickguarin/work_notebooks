# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
data = pd.read_excel('GDP-unemployment-remittances.xlsx', sheet_name='Data')
data = data.iloc[:,1:]
data
# Out:
#       Quarter  Gross Domestic Product  Unemployment Rate  Remittances
# 0  2000-01-01                  850396                9.5      1602756
# 1  2000-04-01                  904732               13.9      1497695
# 2  2000-07-01                  913644               11.2      1503752
# 3  2000-10-01                 1028784               10.1      1446247
# 4  2001-01-01                  925936               11.3      1354419
# ..        ...                     ...                ...          ...
# 76 2019-01-01                 4422951                5.2      7298664
# 77 2019-04-01                 4857262                5.1      7339633
# 78 2019-07-01                 4729028                5.4      7548990
# 79 2019-10-01                 5507177                4.5      7946013
# 80 2020-01-01                 4473250                5.3      7402545
#
# [81 rows x 4 columns]

# %%
data['lnGDP'] = np.log(data['Gross Domestic Product'])
data['lnRemit'] = np.log(data['Remittances'])
data
# Out:
#       Quarter  Gross Domestic Product  Unemployment Rate  Remittances  \
# 0  2000-01-01                  850396                9.5      1602756
# 1  2000-04-01                  904732               13.9      1497695
# 2  2000-07-01                  913644               11.2      1503752
# 3  2000-10-01                 1028784               10.1      1446247
# 4  2001-01-01                  925936               11.3      1354419
# ..        ...                     ...                ...          ...
# 76 2019-01-01                 4422951                5.2      7298664
# 77 2019-04-01                 4857262                5.1      7339633
# 78 2019-07-01                 4729028                5.4      7548990
# 79 2019-10-01                 5507177                4.5      7946013
# 80 2020-01-01                 4473250                5.3      7402545
#
#         lnGDP    lnRemit
# 0   13.653457  14.287235
# 1   13.715394  14.219438
# 2   13.725196  14.223474
# ...

# %%
fig = plt.figure(figsize=(15,8), dpi = 100)
data.plot(x='Quarter', y=['Gross Domestic Product','Remittances'], kind='line')
#data.plot(x='Quarter', y='lnRemit', kind='line')
#fig.suptitle('GDP plot', fontsize=28)
#plt.plot(data)
#plt.axhline(y = last_price, color = 'r', linestyle = '-')
#plt.xlabel('Quarter', fontsize=20)
#plt.ylabel('Y', fontsize=20)
plt.show()
