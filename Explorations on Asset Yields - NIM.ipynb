# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from statsmodels.tsa.stattools import adfuller, grangercausalitytests
from statsmodels.tsa.statespace.sarimax import SARIMAX 
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
from itertools import combinations
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:23: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %% [markdown]
# -------------------------
# *up bond yield, lower policy and vice versa*
#
# bond yields > asset yields
#
# policy rate + gdp > loans > asset yields
#
# CASA level and policy rates > COF
#
# asset yields + COF > NII

# %% [markdown]
# ### Data Preprocessing

# %%
data = os.path.join('datasets', '9M21_asset_yield_data.csv')

df = pd.read_csv(data, parse_dates=[0], index_col=0, squeeze=True)

df.head(-1)
# Out:
#             olf  policy    loans_ukb  loans_gth_ukb  loans_pbs  loans_gth_pbs  \
# 1998-01-01  NaN     NaN          NaN            NaN        NaN            NaN
# 1998-02-01  NaN     NaN          NaN            NaN        NaN            NaN
# 1998-03-01  NaN     NaN          NaN            NaN        NaN            NaN
# 1998-04-01  NaN     NaN          NaN            NaN        NaN            NaN
# 1998-05-01  NaN     NaN          NaN            NaN        NaN            NaN
# ...         ...     ...          ...            ...        ...            ...
# 2021-04-01  2.5     2.0  9277722.090         -0.029   8493.096         -0.036
# 2021-05-01  2.5     2.0  9292945.910         -0.018   8505.526         -0.027
# 2021-06-01  2.5     2.0  9378985.497         -0.008   8600.542         -0.003
# 2021-07-01  2.5     2.0  9396430.826         -0.005   8619.759          0.010
# 2021-08-01  2.5     2.0  9487686.034          0.016   8713.487          0.031
#
#             yield_ukb  cof_ukb  nim_ukb  yield_pbs  ...   gdp_gth   t10yr  \
# 1998-01-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 1998-02-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 1998-03-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 1998-04-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 1998-05-01        NaN      NaN      NaN        NaN  ...       NaN  18.346
# ...               ...      ...      ...        ...  ...       ...     ...
# 2021-04-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 2021-05-01        NaN      NaN      NaN        NaN  ...       NaN     NaN
# 2021-06-01       4.05    0.744    3.394      4.357  ...  0.118095   3.185
# 2021-07-01        NaN      NaN      NaN        NaN  ...       NaN   4.000
# 2021-08-01        NaN      NaN      NaN        NaN  ...       NaN   3.914
#
#             t91day    t5yr  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# 1998-01-01  19.098     NaN          NaN          NaN          NaN
# 1998-02-01  17.789     NaN          NaN          NaN          NaN
# 1998-03-01  16.597  19.647          NaN          NaN          NaN
# 1998-04-01  15.202     NaN          NaN          NaN          NaN
# 1998-05-01  14.377     NaN          NaN          NaN          NaN
# ...            ...     ...          ...          ...          ...
# 2021-04-01   1.335   3.301          NaN          NaN          NaN
# 2021-05-01   1.270   3.295          NaN          NaN          NaN
# 2021-06-01   1.108     NaN          NaN          NaN          NaN
# 2021-07-01   1.061     NaN          NaN          NaN          NaN
# 2021-08-01   1.067     NaN          NaN          NaN          NaN
#
#             Unnamed: 23  Unnamed: 24  Unnamed: 25
# 1998-01-01          NaN          NaN          NaN
# 1998-02-01          NaN          NaN          NaN
# 1998-03-01          NaN          NaN          NaN
# 1998-04-01          NaN          NaN          NaN
# 1998-05-01          NaN          NaN          NaN
# ...                 ...          ...          ...
# 2021-04-01          NaN          NaN          NaN
# 2021-05-01          NaN          NaN          NaN
# 2021-06-01          NaN          NaN          NaN
# 2021-07-01          NaN          NaN          NaN
# 2021-08-01          NaN          NaN          NaN
#
# [284 rows x 25 columns]

# %%
gdp = df.real_gdp.dropna()
loans = df.loans_ukb.dropna() 
gdp_gth = df.gdp_gth.dropna() #
loans_gth = df.loans_gth_ukb.dropna() #
deposits = df.deposits_ukb.dropna()
olf = df.olf.dropna() #
policy = df.policy.dropna()#
asset_yld = df.yield_ukb.dropna() #
asset_yld = df.yield_pbs.dropna() 
cof = df.cof_ukb.dropna() #
nim = df.nim_ukb.dropna() #
#t10yr = bonds.dropna() # <-changed to quarterly averages
t10yr = df.t10yr.dropna()
t91day = df.t91day.dropna() #
t5yr = df.t5yr.dropna() #


series_asset_yld1 = [asset_yld, gdp_gth, policy, olf]
series_asset_yld2 = [asset_yld, t10yr, t91day, t5yr]
series_cof = [cof, deposits, policy]
series_nim = [nim, asset_yld, cof]
series_loan = [loans_gth, gdp_gth, policy, olf]

# %%
# plotting
def plots():

    sns.set(style="darkgrid")

    fig = plt.figure(figsize=(12,24))
    #fig = plt.figure(figsize=(12,12))

    plt.subplot(4, 1, 1)
    plt.plot(gdp_gth, color='darkred', label='Real GDP Growth (2018p)')
    plt.plot(loans_gth, color='tab:blue', label='UKB Loans Growth')
    plt.title('GDP and Loans Growth (1Q98-3Q21)')
    plt.legend(loc=3)
    plt.xlabel('Years')
    plt.ylabel('%')
    plt.axhline(linewidth=1, linestyle='dashed', color='k')

    plt.subplot(4, 1, 2)
    plt.plot(policy, color='tab:blue', label='Reverse Repurchase Rate')
    plt.plot(olf, color='darkred', label='Overnight Lending Facility')
    plt.title('Key Policy Rates (1Q98-3Q21)')
    plt.legend(loc=3)
    plt.xlabel('Years')
    #plt.ylabel('Y-o-Y Growth')

    plt.subplot(4, 1, 3)
    plt.plot(nim, color='darkred', label='Net Interest Margin')
    plt.plot(asset_yld, color='tab:blue', label='Asset Yields')
    plt.plot(cof, color='orange', label='Cost of Funds')
    plt.title('Net Interest Margins (1Q98-3Q21)')
    plt.legend()
    plt.xlabel('Years')
    #plt.ylabel('index')

    plt.subplot(4, 1, 4)
    plt.plot(t10yr.bfill(), color='darkred', label='PH 10-Year Bonds Rate')
    plt.plot(t5yr.bfill(), color='orange', label='PH 5-Year Bonds Rate')
    plt.plot(t91day.bfill(), color='m', label='PH 91-Day Bills Rate')
    plt.title('Bond Yields (1Q98-3Q21)')
    plt.legend()
    plt.xlabel('Years')
    plt.ylabel('% Yield')

    plt.show()

plots()

# %%
# checking for normality by plotting

def all_dist():
    fig = plt.figure(figsize=(12,24))

    plt.subplot(5,2,1)
    plt.hist(gdp_gth)
    plt.title('GDP Growth Distribution')
    plt.ylabel('Count')

    plt.subplot(5,2,2)
    plt.hist(loans_gth)
    plt.title('Loan Growth Distribution')
    plt.ylabel('Count')

    plt.subplot(5, 2, 3)
    plt.hist(asset_yld)
    plt.title('Asset Yields Distribution')
    plt.ylabel('Count')

    plt.subplot(5, 2, 4)
    plt.hist(cof)
    plt.title('Funding Cost Distribution')
    plt.ylabel('Count')

    plt.subplot(5, 2, 5)
    plt.hist(nim)
    plt.title('NIM Distribution')
    plt.ylabel('Count')

    plt.subplot(5, 2, 6)
    plt.hist(policy)
    plt.title('Policy Distribution')
    plt.ylabel('Count')

    plt.subplot(5, 2, 7)
    plt.hist(olf)
    plt.title('OLF Distribution')
    plt.ylabel('Count')
    
    plt.subplot(5, 2, 8)
    plt.hist(t10yr)
    plt.title('10-Year Yield Distribution')
    plt.ylabel('Count')
    
    plt.subplot(5, 2, 9)
    plt.hist(t5yr)
    plt.title('5-Year Yield Distribution')
    plt.ylabel('Count')
    
    plt.subplot(5, 2, 10)
    plt.hist(t91day)
    plt.title('91-Day Yield Distribution')
    plt.ylabel('Count')

    plt.show()
    
all_dist()

# %% [markdown]
# ### Test for Stationarity

# %%
#testing for stationarity

def adf_test(series, name=None, num=None):
    result = adfuller(series)
    if name == None:
        name = str(series.name)
    if num != None:
        name = 'Series %s' % str(num)
    print('\n%s:' %name)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])

# 
series = [loans_gth, gdp_gth, asset_yld, cof, nim, policy, olf, t10yr, t5yr, t91day]
    
for s in series:
    adf_test(s)
# Out:
# loans_gth_ukb:
# ADF Statistic: -2.052273
# p-value: 0.264134
#
# gdp_gth:
# ADF Statistic: -6.522798
# p-value: 0.000000
#
# yield_pbs:
# ADF Statistic: -2.083811
# p-value: 0.251074
#
# cof_ukb:
# ADF Statistic: -2.435273
# p-value: 0.132027
#
# nim_ukb:
# ADF Statistic: -1.338827
# p-value: 0.611227
#
# policy:
# ADF Statistic: -1.043491
# p-value: 0.737073
#
# olf:
# ADF Statistic: -1.650623
# p-value: 0.456715
#
# t10yr:
# ADF Statistic: -2.163036
# p-value: 0.219934
#
# t5yr:
# ADF Statistic: -2.395297
# p-value: 0.143068
#
# t91day:
# ADF Statistic: -3.243443
# p-value: 0.017604

# %% [markdown]
# ### Transformation
# - Normalization,
# - Differencing,
# - Treating unequal variance,
# - Adjusting for seasonality

# %% [markdown]
# #### Making Stationary

# %%
def normalize(series):
    ave, stdev = series.mean(), series.std()
    series = (series-ave)/stdev
    return series

def annual_vol(series):
    stdevs = series.groupby(series.index.year).std()
    return series.index.map(lambda d: stdevs.loc[d.year])

def variance_correct(series):
    return series/annual_vol(series)

def qtr_mean(series):
    means = series.groupby(series.index.month).mean()
    return series.index.map(lambda d: means.loc[d.month])

def seasonality_correct(series):
    return series - qtr_mean(series)

def make_stationary(*data, plot=False, headers=True):
    stdata = []
    for d in data:
        if headers == True:
            header = d.name
        d = normalize(d)
        d = d.diff().dropna()
        # d = annual_vol(d)
        d = variance_correct(d)
        d = seasonality_correct(d).dropna()
        d.name = header
        stdata.append(d)
        
    if len(stdata) == 1:
        return stdata[0]
    else:
        return stdata

# %%
series = make_stationary(loans_gth, gdp_gth, asset_yld, cof, nim, policy, olf, t10yr, t5yr, t91day)

for s in series:
    adf_test(s)
# Out:
# loans_gth_ukb:
# ADF Statistic: -5.974838
# p-value: 0.000000
#
# gdp_gth:
# ADF Statistic: -8.659613
# p-value: 0.000000
#
# yield_pbs:
# ADF Statistic: -2.926498
# p-value: 0.042352
#
# cof_ukb:
# ADF Statistic: -2.495554
# p-value: 0.116560
#
# nim_ukb:
# ADF Statistic: -1.350559
# p-value: 0.605736
#
# policy:
# ADF Statistic: -4.180204
# p-value: 0.000712
#
# olf:
# ADF Statistic: -3.890438
# p-value: 0.002106
#
# t10yr:
# ADF Statistic: -9.464898
# p-value: 0.000000
#
# t5yr:
# ADF Statistic: -10.234654
# p-value: 0.000000
#
# t91day:
# ADF Statistic: -7.766089
# p-value: 0.000000

# %%
loans_gth = make_stationary(loans_gth)
gdp_gth = make_stationary(gdp_gth)
asset_yld = make_stationary(asset_yld)
cof = make_stationary(cof)
nim = make_stationary(nim)
policy = make_stationary(policy)
olf = make_stationary(olf)
t10yr = make_stationary(t10yr)
t5yr = make_stationary(t5yr)
t91day = make_stationary(t91day)

# %%
sns.set(style="darkgrid")

fig = plt.figure(figsize=(12,24))

plt.subplot(4, 1, 1)
plt.plot(gdp_gth, color='darkred', label='Real GDP Growth (2018p)')
plt.plot(loans_gth, color='tab:blue', label='UKB Loans Growth')
plt.title('GDP and Loans Growth (1Q98-3Q21)')
plt.legend(loc=3)
plt.xlabel('Years')
plt.ylabel('%')
plt.axhline(linewidth=1, linestyle='dashed', color='k')

plt.subplot(4, 1, 2)
plt.plot(policy, color='tab:blue', label='Reverse Repurchase Rate')
plt.plot(olf, color='darkred', label='Overnight Lending Facility')
plt.title('Key Policy Rates (1Q98-3Q21)')
plt.legend(loc=3)
plt.xlabel('Years')
#plt.ylabel('Y-o-Y Growth')

plt.subplot(4, 1, 3)
plt.plot(nim, color='darkred', label='Net Interest Margin')
plt.plot(asset_yld, color='tab:blue', label='Asset Yields')
plt.plot(cof, color='orange', label='Cost of Funds')
plt.title('Net Interest Margins (1Q98-3Q21)')
plt.legend()
plt.xlabel('Years')
plt.axhline(linewidth=1, linestyle='dashed', color='k')

plt.subplot(4, 1, 4)
plt.plot(t10yr.bfill(), color='darkred', label='PH 10-Year Bonds Rate')
plt.plot(t5yr.bfill(), color='orange', label='PH 5-Year Bonds Rate')
plt.plot(t91day.bfill(), color='m', label='PH 91-Day Bills Rate')
plt.title('Bond Yields (1Q98-3Q21)')
plt.legend()
plt.xlabel('Years')
plt.ylabel('% Yield')
plt.axhline(linewidth=1, linestyle='dashed', color='k')

plt.show()

# %% [markdown]
# ### Running Granger Causality on Corrected Data

# %%
def granger(s1, s2, lag=6):
    granger_df = pd.concat([s1, s2], axis=1).dropna()
    grangercausalitytests(granger_df, lag)
    
comb = [[loans_gth, gdp_gth], #1
       [loans_gth, policy], #2
       [nim, cof], #3
       [nim, asset_yld], #4
       [cof, policy], #5
       [nim, policy], #6
       [asset_yld, gdp_gth],#7
       [asset_yld, policy], #8
       [asset_yld, t10yr], #9
       [asset_yld, t5yr], #10
       [asset_yld, t91day]] #11

# %%
#try on every combination
num = 0
for c in comb:
    num += 1
    print('Granger Causality Results for Relation %s' %str(num))
    print('-------------------------------------------------')
    print('\nBetween %s' %str(c[0].name)+' and '+str(c[1].name))
    print('\n%s as Affected: ' %str(c[0].name))
    granger(c[0], c[1], lag=4)
    print('\n%s as Affected: ' %str(c[1].name))
    granger(c[1], c[0], lag=4)
    print('\n=================================================\n')
# Out:
# Granger Causality Results for Relation 1
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0108  , p=0.9175  , df_denom=70, df_num=1
# ssr based chi2 test:   chi2=0.0113  , p=0.9155  , df=1
# likelihood ratio test: chi2=0.0113  , p=0.9155  , df=1
# parameter F test:         F=0.0108  , p=0.9175  , df_denom=70, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3760  , p=0.2596  , df_denom=67, df_num=2
# ssr based chi2 test:   chi2=2.9573  , p=0.2279  , df=2
# likelihood ratio test: chi2=2.8982  , p=0.2348  , df=2
# parameter F test:         F=1.3760  , p=0.2596  , df_denom=67, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9181  , p=0.4373  , df_denom=64, df_num=3
# ssr based chi2 test:   chi2=3.0555  , p=0.3831  , df=3
# likelihood ratio test: chi2=2.9916  , p=0.3929  , df=3
# parameter F test:         F=0.9181  , p=0.4373  , df_denom=64, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6820  , p=0.6071  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.1307  , p=0.5362  , df=4
# likelihood ratio test: chi2=3.0627  , p=0.5474  , df=4
# parameter F test:         F=0.6820  , p=0.6071  , df_denom=61, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9086  , p=0.3438  , df_denom=70, df_num=1
# ssr based chi2 test:   chi2=0.9475  , p=0.3303  , df=1
# likelihood ratio test: chi2=0.9414  , p=0.3319  , df=1
# parameter F test:         F=0.9086  , p=0.3438  , df_denom=70, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2650  , p=0.2889  , df_denom=67, df_num=2
# ssr based chi2 test:   chi2=2.7188  , p=0.2568  , df=2
# likelihood ratio test: chi2=2.6687  , p=0.2633  , df=2
# parameter F test:         F=1.2650  , p=0.2889  , df_denom=67, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8333  , p=0.4805  , df_denom=64, df_num=3
# ssr based chi2 test:   chi2=2.7734  , p=0.4279  , df=3
# likelihood ratio test: chi2=2.7206  , p=0.4367  , df=3
# parameter F test:         F=0.8333  , p=0.4805  , df_denom=64, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8605  , p=0.4928  , df_denom=61, df_num=4
# ssr based chi2 test:   chi2=3.9498  , p=0.4128  , df=4
# likelihood ratio test: chi2=3.8424  , p=0.4278  , df=4
# parameter F test:         F=0.8605  , p=0.4928  , df_denom=61, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 2
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9641  , p=0.0873  , df_denom=140, df_num=1
# ssr based chi2 test:   chi2=3.0277  , p=0.0819  , df=1
# likelihood ratio test: chi2=2.9960  , p=0.0835  , df=1
# parameter F test:         F=2.9641  , p=0.0873  , df_denom=140, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4548  , p=0.2370  , df_denom=137, df_num=2
# ssr based chi2 test:   chi2=3.0158  , p=0.2214  , df=2
# likelihood ratio test: chi2=2.9842  , p=0.2249  , df=2
# parameter F test:         F=1.4548  , p=0.2370  , df_denom=137, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4770  , p=0.6988  , df_denom=134, df_num=3
# ssr based chi2 test:   chi2=1.5058  , p=0.6809  , df=3
# likelihood ratio test: chi2=1.4978  , p=0.6828  , df=3
# parameter F test:         F=0.4770  , p=0.6988  , df_denom=134, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6821  , p=0.1579  , df_denom=131, df_num=4
# ssr based chi2 test:   chi2=7.1907  , p=0.1261  , df=4
# likelihood ratio test: chi2=7.0121  , p=0.1352  , df=4
# parameter F test:         F=1.6821  , p=0.1579  , df_denom=131, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4466  , p=0.5050  , df_denom=140, df_num=1
# ssr based chi2 test:   chi2=0.4562  , p=0.4994  , df=1
# likelihood ratio test: chi2=0.4555  , p=0.4997  , df=1
# parameter F test:         F=0.4466  , p=0.5050  , df_denom=140, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.3369  , p=0.0149  , df_denom=137, df_num=2
# ssr based chi2 test:   chi2=8.9904  , p=0.0112  , df=2
# likelihood ratio test: chi2=8.7173  , p=0.0128  , df=2
# parameter F test:         F=4.3369  , p=0.0149  , df_denom=137, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5603  , p=0.0576  , df_denom=134, df_num=3
# ssr based chi2 test:   chi2=8.0821  , p=0.0443  , df=3
# likelihood ratio test: chi2=7.8590  , p=0.0490  , df=3
# parameter F test:         F=2.5603  , p=0.0576  , df_denom=134, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.0950  , p=0.0850  , df_denom=131, df_num=4
# ssr based chi2 test:   chi2=8.9559  , p=0.0622  , df=4
# likelihood ratio test: chi2=8.6811  , p=0.0696  , df=4
# parameter F test:         F=2.0950  , p=0.0850  , df_denom=131, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 3
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.2279  , p=0.0061  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=8.7317  , p=0.0031  , df=1
# likelihood ratio test: chi2=8.0715  , p=0.0045  , df=1
# parameter F test:         F=8.2279  , p=0.0061  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6788  , p=0.0062  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=12.5922 , p=0.0018  , df=2
# likelihood ratio test: chi2=11.2539 , p=0.0036  , df=2
# parameter F test:         F=5.6788  , p=0.0062  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.7056  , p=0.0186  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=12.9265 , p=0.0048  , df=3
# likelihood ratio test: chi2=11.4972 , p=0.0093  , df=3
# parameter F test:         F=3.7056  , p=0.0186  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.4645  , p=0.0045  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=21.8759 , p=0.0002  , df=4
# likelihood ratio test: chi2=18.0864 , p=0.0012  , df=4
# parameter F test:         F=4.4645  , p=0.0045  , df_denom=40, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2585  , p=0.6134  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=0.2744  , p=0.6004  , df=1
# likelihood ratio test: chi2=0.2736  , p=0.6009  , df=1
# parameter F test:         F=0.2585  , p=0.6134  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9980  , p=0.3764  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=2.2130  , p=0.3307  , df=2
# likelihood ratio test: chi2=2.1663  , p=0.3385  , df=2
# parameter F test:         F=0.9980  , p=0.3764  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4459  , p=0.7215  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=1.5554  , p=0.6695  , df=3
# likelihood ratio test: chi2=1.5317  , p=0.6750  , df=3
# parameter F test:         F=0.4459  , p=0.7215  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1532  , p=0.9605  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=0.7506  , p=0.9449  , df=4
# likelihood ratio test: chi2=0.7449  , p=0.9457  , df=4
# parameter F test:         F=0.1532  , p=0.9605  , df_denom=40, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 4
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.1606  , p=0.0101  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=7.5990  , p=0.0058  , df=1
# likelihood ratio test: chi2=7.0926  , p=0.0077  , df=1
# parameter F test:         F=7.1606  , p=0.0101  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.3372  , p=0.0443  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=7.3998  , p=0.0247  , df=2
# likelihood ratio test: chi2=6.9099  , p=0.0316  , df=2
# parameter F test:         F=3.3372  , p=0.0443  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4166  , p=0.0794  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=8.4299  , p=0.0379  , df=3
# likelihood ratio test: chi2=7.7902  , p=0.0506  , df=3
# parameter F test:         F=2.4166  , p=0.0794  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9589  , p=0.1195  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=9.5986  , p=0.0478  , df=4
# likelihood ratio test: chi2=8.7656  , p=0.0672  , df=4
# parameter F test:         F=1.9589  , p=0.1195  , df_denom=40, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6995  , p=0.4070  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=0.7423  , p=0.3889  , df=1
# likelihood ratio test: chi2=0.7371  , p=0.3906  , df=1
# parameter F test:         F=0.6995  , p=0.4070  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3805  , p=0.6856  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=0.8438  , p=0.6558  , df=2
# likelihood ratio test: chi2=0.8369  , p=0.6581  , df=2
# parameter F test:         F=0.3805  , p=0.6856  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7437  , p=0.5320  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=2.5941  , p=0.4585  , df=3
# likelihood ratio test: chi2=2.5291  , p=0.4701  , df=3
# parameter F test:         F=0.7437  , p=0.5320  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4740  , p=0.7545  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=2.3226  , p=0.6767  , df=4
# likelihood ratio test: chi2=2.2693  , p=0.6864  , df=4
# parameter F test:         F=0.4740  , p=0.7545  , df_denom=40, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 5
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.3916  , p=0.0168  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=7.0102  , p=0.0081  , df=1
# likelihood ratio test: chi2=6.3736  , p=0.0116  , df=1
# parameter F test:         F=6.3916  , p=0.0168  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.5277  , p=0.0047  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=15.3868 , p=0.0005  , df=2
# likelihood ratio test: chi2=12.6298 , p=0.0018  , df=2
# parameter F test:         F=6.5277  , p=0.0047  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.9668  , p=0.0193  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=15.2324 , p=0.0016  , df=3
# likelihood ratio test: chi2=12.4590 , p=0.0060  , df=3
# parameter F test:         F=3.9668  , p=0.0193  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8670  , p=0.0472  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=16.1592 , p=0.0028  , df=4
# likelihood ratio test: chi2=13.0058 , p=0.0112  , df=4
# parameter F test:         F=2.8670  , p=0.0472  , df_denom=22, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3125  , p=0.5802  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=0.3427  , p=0.5583  , df=1
# likelihood ratio test: chi2=0.3410  , p=0.5592  , df=1
# parameter F test:         F=0.3125  , p=0.5802  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2357  , p=0.7916  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=0.5556  , p=0.7574  , df=2
# likelihood ratio test: chi2=0.5510  , p=0.7592  , df=2
# parameter F test:         F=0.2357  , p=0.7916  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7846  , p=0.5138  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=3.0130  , p=0.3896  , df=3
# likelihood ratio test: chi2=2.8794  , p=0.4106  , df=3
# parameter F test:         F=0.7846  , p=0.5138  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7280  , p=0.5824  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=4.1033  , p=0.3922  , df=4
# likelihood ratio test: chi2=3.8535  , p=0.4262  , df=4
# parameter F test:         F=0.7280  , p=0.5824  , df_denom=22, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 6
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.9866  , p=0.0939  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=3.2756  , p=0.0703  , df=1
# likelihood ratio test: chi2=3.1273  , p=0.0770  , df=1
# parameter F test:         F=2.9866  , p=0.0939  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7747  , p=0.1881  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=4.1831  , p=0.1235  , df=2
# likelihood ratio test: chi2=3.9385  , p=0.1396  , df=2
# parameter F test:         F=1.7747  , p=0.1881  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6020  , p=0.2140  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=6.1517  , p=0.1045  , df=3
# likelihood ratio test: chi2=5.6267  , p=0.1313  , df=3
# parameter F test:         F=1.6020  , p=0.2140  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3305  , p=0.0877  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=13.1357 , p=0.0106  , df=4
# likelihood ratio test: chi2=10.9517 , p=0.0271  , df=4
# parameter F test:         F=2.3305  , p=0.0877  , df_denom=22, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0711  , p=0.7915  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=0.0780  , p=0.7801  , df=1
# likelihood ratio test: chi2=0.0779  , p=0.7802  , df=1
# parameter F test:         F=0.0711  , p=0.7915  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1478  , p=0.8632  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=0.3484  , p=0.8401  , df=2
# likelihood ratio test: chi2=0.3466  , p=0.8409  , df=2
# parameter F test:         F=0.1478  , p=0.8632  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4316  , p=0.7322  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=1.6573  , p=0.6465  , df=3
# likelihood ratio test: chi2=1.6158  , p=0.6558  , df=3
# parameter F test:         F=0.4316  , p=0.7322  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4959  , p=0.2377  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=8.4316  , p=0.0770  , df=4
# likelihood ratio test: chi2=7.4580  , p=0.1136  , df=4
# parameter F test:         F=1.4959  , p=0.2377  , df_denom=22, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 7
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4758  , p=0.2303  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=1.5661  , p=0.2108  , df=1
# likelihood ratio test: chi2=1.5430  , p=0.2142  , df=1
# parameter F test:         F=1.4758  , p=0.2303  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1197  , p=0.3351  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=2.4827  , p=0.2890  , df=2
# likelihood ratio test: chi2=2.4242  , p=0.2976  , df=2
# parameter F test:         F=1.1197  , p=0.3351  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4141  , p=0.2517  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=4.9328  , p=0.1768  , df=3
# likelihood ratio test: chi2=4.7044  , p=0.1948  , df=3
# parameter F test:         F=1.4141  , p=0.2517  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0119  , p=0.4128  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=4.9585  , p=0.2916  , df=4
# likelihood ratio test: chi2=4.7233  , p=0.3169  , df=4
# parameter F test:         F=1.0119  , p=0.4128  , df_denom=40, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6038  , p=0.4409  , df_denom=49, df_num=1
# ssr based chi2 test:   chi2=0.6407  , p=0.4234  , df=1
# likelihood ratio test: chi2=0.6368  , p=0.4249  , df=1
# parameter F test:         F=0.6038  , p=0.4409  , df_denom=49, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3810  , p=0.6853  , df_denom=46, df_num=2
# ssr based chi2 test:   chi2=0.8447  , p=0.6555  , df=2
# likelihood ratio test: chi2=0.8378  , p=0.6578  , df=2
# parameter F test:         F=0.3810  , p=0.6853  , df_denom=46, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0909  , p=0.3632  , df_denom=43, df_num=3
# ssr based chi2 test:   chi2=3.8056  , p=0.2832  , df=3
# likelihood ratio test: chi2=3.6678  , p=0.2996  , df=3
# parameter F test:         F=1.0909  , p=0.3632  , df_denom=43, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5977  , p=0.6664  , df_denom=40, df_num=4
# ssr based chi2 test:   chi2=2.9288  , p=0.5698  , df=4
# likelihood ratio test: chi2=2.8446  , p=0.5842  , df=4
# parameter F test:         F=0.5977  , p=0.6664  , df_denom=40, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 8
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.9265  , p=0.0565  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=4.3065  , p=0.0380  , df=1
# likelihood ratio test: chi2=4.0548  , p=0.0440  , df=1
# parameter F test:         F=3.9265  , p=0.0565  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0559  , p=0.1469  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=4.8460  , p=0.0887  , df=2
# likelihood ratio test: chi2=4.5216  , p=0.1043  , df=2
# parameter F test:         F=2.0559  , p=0.1469  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0708  , p=0.1296  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=7.9519  , p=0.0470  , df=3
# likelihood ratio test: chi2=7.1021  , p=0.0687  , df=3
# parameter F test:         F=2.0708  , p=0.1296  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5956  , p=0.2108  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=8.9931  , p=0.0613  , df=4
# likelihood ratio test: chi2=7.8963  , p=0.0955  , df=4
# parameter F test:         F=1.5956  , p=0.2108  , df_denom=22, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0127  , p=0.9112  , df_denom=31, df_num=1
# ssr based chi2 test:   chi2=0.0139  , p=0.9062  , df=1
# likelihood ratio test: chi2=0.0139  , p=0.9062  , df=1
# parameter F test:         F=0.0127  , p=0.9112  , df_denom=31, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4753  , p=0.6266  , df_denom=28, df_num=2
# ssr based chi2 test:   chi2=1.1204  , p=0.5711  , df=2
# likelihood ratio test: chi2=1.1018  , p=0.5764  , df=2
# parameter F test:         F=0.4753  , p=0.6266  , df_denom=28, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1071  , p=0.0445  , df_denom=25, df_num=3
# ssr based chi2 test:   chi2=11.9313 , p=0.0076  , df=3
# likelihood ratio test: chi2=10.1405 , p=0.0174  , df=3
# parameter F test:         F=3.1071  , p=0.0445  , df_denom=25, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4254  , p=0.0785  , df_denom=22, df_num=4
# ssr based chi2 test:   chi2=13.6703 , p=0.0084  , df=4
# likelihood ratio test: chi2=11.3249 , p=0.0231  , df=4
# parameter F test:         F=2.4254  , p=0.0785  , df_denom=22, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 9
# -------------------------------------------------
#
# Var A as Affected:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2597  , p=0.6178  , df_denom=15, df_num=1
# ssr based chi2 test:   chi2=0.3116  , p=0.5767  , df=1
# likelihood ratio test: chi2=0.3089  , p=0.5783  , df=1
# parameter F test:         F=0.2597  , p=0.6178  , df_denom=15, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3770  , p=0.6938  , df_denom=12, df_num=2
# ssr based chi2 test:   chi2=1.0682  , p=0.5862  , df=2
# likelihood ratio test: chi2=1.0359  , p=0.5957  , df=2
# parameter F test:         F=0.3770  , p=0.6938  , df_denom=12, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7226  , p=0.5634  , df_denom=9, df_num=3
# ssr based chi2 test:   chi2=3.8537  , p=0.2777  , df=3
# likelihood ratio test: chi2=3.4528  , p=0.3269  , df=3
# parameter F test:         F=0.7226  , p=0.5634  , df_denom=9, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.4668  , p=0.7595  , df_denom=6, df_num=4
# ssr based chi2 test:   chi2=4.6680  , p=0.3231  , df=4
# likelihood ratio test: chi2=4.0641  , p=0.3974  , df=4
# parameter F test:         F=0.4668  , p=0.7595  , df_denom=6, df_num=4
#
# Var A as Affecting:
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2276  , p=0.6402  , df_denom=15, df_num=1
# ssr based chi2 test:   chi2=0.2732  , p=0.6012  , df=1
# likelihood ratio test: chi2=0.2711  , p=0.6026  , df=1
# parameter F test:         F=0.2276  , p=0.6402  , df_denom=15, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.1087  , p=0.0437  , df_denom=12, df_num=2
# ssr based chi2 test:   chi2=11.6413 , p=0.0030  , df=2
# likelihood ratio test: chi2=8.8678  , p=0.0119  , df=2
# parameter F test:         F=4.1087  , p=0.0437  , df_denom=12, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7388  , p=0.1054  , df_denom=9, df_num=3
# ssr based chi2 test:   chi2=14.6068 , p=0.0022  , df=3
# likelihood ratio test: chi2=10.3781 , p=0.0156  , df=3
# parameter F test:         F=2.7388  , p=0.1054  , df_denom=9, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1491  , p=0.1018  , df_denom=6, df_num=4
# ssr based chi2 test:   chi2=31.4909 , p=0.0000  , df=4
# likelihood ratio test: chi2=16.9681 , p=0.0020  , df=4
# parameter F test:         F=3.1491  , p=0.1018  , df_denom=6, df_num=4
#
# =================================================
#
# Granger Causality Results for Relation 10
# -------------------------------------------------
#
# Var A as Affected:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-8236bcb24abb> in <module>
#       6     print('-------------------------------------------------')
#       7     print('\nVar A as Affected: ')
# ----> 8     granger(c[0], c[1], lag=4)
#       9     print('\nVar A as Affecting: ')
#      10     granger(c[1], c[0], lag=4)
#
# <ipython-input-18-95bd2b896515> in granger(s1, s2, lag)
#       1 def granger(s1, s2, lag=6):
#       2     granger_df = pd.concat([s1, s2], axis=1).dropna()
# ----> 3     grangercausalitytests(granger_df, lag)
#       4
#       5 comb = [[loans_gth, gdp_gth], #1
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in grangercausalitytests(x, maxlag, addconst, verbose)
#    1240         raise ValueError("Insufficient observations. Maximum allowable "
#    1241                          "lag is {0}".format(int((x.shape[0] - int(addconst)) /
# -> 1242                                                  3) - 1))
#    1243
#    1244     resli = {}
#
# ValueError: Insufficient observations. Maximum allowable lag is 2

# %% [markdown]
# ### Model Fitting

# %%
# Plotting partial autocorrelation
series = [nim, policy, t10yr, t5yr, t91day]
s_names = ['NIM', 'Policy', 'PH 10YR', 'PH 5YR', 'PH 91D']

ind = 0
for s in series:
    print('%s:'%s_names[ind])
    plot_pacf(s)
    ind += 1
    plt.show()
# Out:
# NIM:
# Policy:
# PH 10YR:
# PH 5YR:
# PH 91D:

# %% [markdown]
# #### Fitting and selecting best model

# %%
## Automate

def fit_tsmodel(data, model='VAR', lags=4):
    models = ['VAR','SARIMAX']

    if model in models:
        if model == models[0]:
            model = VAR
        elif model == models[1]:
            model == SARIMAX
    else:
        print('Model not supported')
        return None
    
    fmodel = model(data)          
    res = fmodel.fit(maxlags=lags)
    return res

def create_df(*series):
    df = pd.concat(series, axis=1).bfill().dropna()
    n = []
    for i in series:
        n.append(i.name)
    df.columns = n
    return df

# %%
# loop through combos
# to check how many possible equations exist
series = [policy, t10yr, t5yr, t91day]
depvar = [asset_yld]
c_list = []
MAX_COMB = 5

# put constraints function where loans/loans grwoth as first item in list
for i in range(1, MAX_COMB):
    l = list(combinations(series, i))
    print('No. of series of combination: %s' %len(l))
    c_list.extend(l)

print('Total no. of combinations: %s \n' %len(c_list))
#print(c_list)
# Out:
# No. of series of combination: 4
# No. of series of combination: 6
# No. of series of combination: 4
# No. of series of combination: 1
# Total no. of combinations: 15

# %%
df1 = create_df(nim, policy, t10yr, t5yr, t91day)
df1 = df1.loc['2008-01-01':]

# %%
res1 = fit_tsmodel(df1,lags=3)
res1.summary()
# Out:
# C:\Users\Derrick\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 27, Oct, 2021
# Time:                     10:02:50
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                  -0.849498
# Nobs:                     152.000    HQIC:                  -1.79448
# Log likelihood:          -812.876    FPE:                  0.0874140
# AIC:                     -2.44101    Det(Omega_mle):       0.0529971
# --------------------------------------------------------------------
# Results for equation nim_ukb
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.031989         0.055874            0.573           0.567
# L1.nim_ukb         0.846925         0.086680            9.771           0.000
# L1.policy          0.078896         0.056453            1.398           0.162
# L1.t10yr          -0.066978         0.065208           -1.027           0.304
# L1.t5yr           -0.065794         0.064475           -1.020           0.308
# L1.t91day          0.100161         0.052624            1.903           0.057
# L2.nim_ukb         0.017323         0.112721            0.154           0.878
# L2.policy         -0.043177         0.056096           -0.770           0.441
# L2.t10yr           0.057080         0.079861            0.715           0.475
# L2.t5yr            0.007421         0.078648            0.094           0.925
# L2.t91day          0.078617         0.055259            1.423           0.155
# L3.nim_ukb        -0.072352         0.083143           -0.870           0.384
# L3.policy         -0.019254         0.055978           -0.344           0.731
# L3.t10yr           0.074545         0.065679            1.135           0.256
# L3.t5yr            0.037511         0.066435            0.565           0.572
# L3.t91day         -0.080180         0.052858           -1.517           0.129
# =============================================================================
#
# Results for equation policy
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.065894         0.087766            0.751           0.453
# L1.nim_ukb         0.074408         0.136157            0.546           0.585
# L1.policy          0.122551         0.088677            1.382           0.167
# L1.t10yr           0.080542         0.102429            0.786           0.432
# L1.t5yr            0.088159         0.101278            0.870           0.384
# L1.t91day          0.035918         0.082662            0.435           0.664
# L2.nim_ukb        -0.332047         0.177063           -1.875           0.061
# L2.policy          0.150270         0.088115            1.705           0.088
# L2.t10yr           0.040253         0.125447            0.321           0.748
# L2.t5yr           -0.060792         0.123541           -0.492           0.623
# L2.t91day          0.010714         0.086800            0.123           0.902
# L3.nim_ukb         0.181466         0.130601            1.389           0.165
# L3.policy          0.160647         0.087931            1.827           0.068
# L3.t10yr           0.051718         0.103168            0.501           0.616
# L3.t5yr           -0.043644         0.104357           -0.418           0.676
# L3.t91day          0.035212         0.083030            0.424           0.672
# =============================================================================
#
# Results for equation t10yr
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.137195         0.074953            1.830           0.067
# L1.nim_ukb         0.043337         0.116279            0.373           0.709
# L1.policy         -0.023821         0.075730           -0.315           0.753
# L1.t10yr           0.728856         0.087475            8.332           0.000
# L1.t5yr            0.147735         0.086491            1.708           0.088
# L1.t91day         -0.012269         0.070593           -0.174           0.862
# L2.nim_ukb        -0.083270         0.151212           -0.551           0.582
# L2.policy         -0.003562         0.075251           -0.047           0.962
# L2.t10yr          -0.008280         0.107132           -0.077           0.938
# L2.t5yr            0.046863         0.105504            0.444           0.657
# L2.t91day         -0.120830         0.074128           -1.630           0.103
# L3.nim_ukb         0.031223         0.111534            0.280           0.780
# L3.policy          0.092071         0.075093            1.226           0.220
# L3.t10yr          -0.069782         0.088106           -0.792           0.428
# L3.t5yr            0.015579         0.089121            0.175           0.861
# L3.t91day          0.017572         0.070907            0.248           0.804
# =============================================================================
#
# Results for equation t5yr
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const             -0.053597         0.076533           -0.700           0.484
# L1.nim_ukb        -0.046814         0.118731           -0.394           0.693
# L1.policy          0.070960         0.077327            0.918           0.359
# L1.t10yr           0.175283         0.089319            1.962           0.050
# L1.t5yr            0.712974         0.088315            8.073           0.000
# L1.t91day         -0.019779         0.072082           -0.274           0.784
# L2.nim_ukb         0.009308         0.154401            0.060           0.952
# L2.policy         -0.079361         0.076838           -1.033           0.302
# L2.t10yr          -0.058426         0.109391           -0.534           0.593
# L2.t5yr           -0.104742         0.107729           -0.972           0.331
# L2.t91day         -0.009082         0.075691           -0.120           0.904
# L3.nim_ukb        -0.003097         0.113885           -0.027           0.978
# L3.policy         -0.014239         0.076677           -0.186           0.853
# L3.t10yr          -0.071482         0.089964           -0.795           0.427
# L3.t5yr            0.123371         0.091000            1.356           0.175
# L3.t91day          0.020504         0.072403            0.283           0.777
# =============================================================================
#
# Results for equation t91day
# =============================================================================
#                 coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------
# const              0.140554         0.089099            1.577           0.115
# L1.nim_ukb        -0.041274         0.138225           -0.299           0.765
# L1.policy          0.164026         0.090023            1.822           0.068
# L1.t10yr           0.114242         0.103985            1.099           0.272
# L1.t5yr            0.322315         0.102816            3.135           0.002
# L1.t91day          0.352713         0.083917            4.203           0.000
# L2.nim_ukb         0.140270         0.179752            0.780           0.435
# L2.policy         -0.012795         0.089454           -0.143           0.886
# L2.t10yr          -0.109819         0.127352           -0.862           0.389
# L2.t5yr           -0.313271         0.125417           -2.498           0.012
# L2.t91day         -0.163459         0.088119           -1.855           0.064
# L3.nim_ukb        -0.142677         0.132584           -1.076           0.282
# L3.policy          0.037094         0.089266            0.416           0.678
# L3.t10yr           0.088443         0.104735            0.844           0.398
# L3.t5yr            0.243504         0.105942            2.298           0.022
# L3.t91day         -0.006448         0.084291           -0.076           0.939
# =============================================================================
#
# Correlation matrix of residuals
#             nim_ukb    policy     t10yr      t5yr    t91day
# nim_ukb    1.000000 -0.199937 -0.044079 -0.017479  0.064899
# policy    -0.199937  1.000000  0.174813  0.212048  0.044567
# t10yr     -0.044079  0.174813  1.000000  0.173159  0.053418
# t5yr      -0.017479  0.212048  0.173159  1.000000  0.127655
# t91day     0.064899  0.044567  0.053418  0.127655  1.000000

# %%
fig = plt.figure(figsize=(18,24))

res1.plot()

# %%
irf = res1.irf(10)
irf.plot(orth=False)

# %%
irf.plot(impulse='t10yr')

# %%
irf.plot(impulse='t5yr')

# %%
irf.plot(impulse='t91day')

# %%
irf.plot(impulse='policy')
